# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('survey_results_public.csv')

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
x=df

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
# ...

# %%
x=x[["Country","EdLevel","YearsCode","YearsCodePro","Employment","ConvertedCompYearly"]]
x=x.rename({"ConvertedCompYearly" : "Salary"}, axis=1)
x.head()
# Out:
#                                              Country  \
# 0                                                NaN
# 1                                             Canada
# 2  United Kingdom of Great Britain and Northern I...
# 3                                             Israel
# 4                           United States of America
#
#                                            EdLevel YearsCode YearsCodePro  \
# 0                                              NaN       NaN          NaN
# 1                                              NaN       NaN          NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)        14            5
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)        20           17
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)         8            3
#
#             Employment    Salary
# 0                  NaN       NaN
# 1  Employed, full-time       NaN
# 2  Employed, full-time   40205.0
# 3  Employed, full-time  215232.0
# ...

# %%
x=x[x["Salary"].notnull()]
x.head()
# Out:
#                                               Country  \
# 2   United Kingdom of Great Britain and Northern I...
# 3                                              Israel
# 8                                         Netherlands
# 10  United Kingdom of Great Britain and Northern I...
# 11                           United States of America
#
#                                             EdLevel YearsCode YearsCodePro  \
# 2   Master’s degree (M.A., M.S., M.Eng., MBA, etc.)        14            5
# 3      Bachelor’s degree (B.A., B.S., B.Eng., etc.)        20           17
# 8   Master’s degree (M.A., M.S., M.Eng., MBA, etc.)         6            6
# 10     Bachelor’s degree (B.A., B.S., B.Eng., etc.)         5            2
# 11     Bachelor’s degree (B.A., B.S., B.Eng., etc.)        12           10
#
#                                            Employment    Salary
# 2                                 Employed, full-time   40205.0
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38071 entries, 2 to 73121
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       38071 non-null  object
#  1   EdLevel       38054 non-null  object
#  2   YearsCode     38001 non-null  object
#  3   YearsCodePro  37935 non-null  object
#  4   Employment    38067 non-null  object
#  5   Salary        38071 non-null  float64
# dtypes: float64(1), object(5)
# memory usage: 2.0+ MB

# %%
x=x.dropna()
x.isnull().sum()
# Out:
# Country         0
# EdLevel         0
# YearsCode       0
# YearsCodePro    0
# Employment      0
# Salary          0
# dtype: int64

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37883 entries, 2 to 73121
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       37883 non-null  object
#  1   EdLevel       37883 non-null  object
#  2   YearsCode     37883 non-null  object
#  3   YearsCodePro  37883 non-null  object
#  4   Employment    37883 non-null  object
#  5   Salary        37883 non-null  float64
# dtypes: float64(1), object(5)
# memory usage: 2.0+ MB

# %%
x['Employment']
x.head()
# Out:
#                                               Country  \
# 2   United Kingdom of Great Britain and Northern I...
# 3                                              Israel
# 8                                         Netherlands
# 10  United Kingdom of Great Britain and Northern I...
# 11                           United States of America
#
#                                             EdLevel YearsCode YearsCodePro  \
# 2   Master’s degree (M.A., M.S., M.Eng., MBA, etc.)        14            5
# 3      Bachelor’s degree (B.A., B.S., B.Eng., etc.)        20           17
# 8   Master’s degree (M.A., M.S., M.Eng., MBA, etc.)         6            6
# 10     Bachelor’s degree (B.A., B.S., B.Eng., etc.)         5            2
# 11     Bachelor’s degree (B.A., B.S., B.Eng., etc.)        12           10
#
#                                            Employment    Salary
# 2                                 Employed, full-time   40205.0
# ...

# %%
#x=x[x['Employment']=='Employed full-time']
x.drop("Employment",axis=1)
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37883 entries, 2 to 73121
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       37883 non-null  object
#  1   EdLevel       37883 non-null  object
#  2   YearsCode     37883 non-null  object
#  3   YearsCodePro  37883 non-null  object
#  4   Employment    37883 non-null  object
#  5   Salary        37883 non-null  float64
# dtypes: float64(1), object(5)
# memory usage: 2.0+ MB

# %%
x['Country'].value_counts()
# Out:
# United States of America                                8675
# Germany                                                 2899
# United Kingdom of Great Britain and Northern Ireland    2648
# India                                                   2150
# Canada                                                  1478
#                                                         ...
# Fiji                                                       1
# Palau                                                      1
# Monaco                                                     1
# Saint Lucia                                                1
# Seychelles                                                 1
# Name: Country, Length: 159, dtype: int64

# %%
def shorten_categories(categories, cutoff):
    categorical_map = {}
    for i in range(len(categories)):
        if categories.values[i] >= cutoff:
            categorical_map[categories.index[i]] = categories.index[i]
        else:
            categorical_map[categories.index[i]] = 'Other'
    return categorical_map

# %%
country_map = shorten_categories(df.Country.value_counts(), 400)
x['Country'] = x['Country'].map(country_map)
x.Country.value_counts()
# Out:
# United States of America                                8675
# Other                                                   4373
# Germany                                                 2899
# United Kingdom of Great Britain and Northern Ireland    2648
# India                                                   2150
# Canada                                                  1478
# France                                                  1370
# Brazil                                                  1276
# Spain                                                    991
# Poland                                                   973
# Netherlands                                              896
# Australia                                                829
# Italy                                                    805
# Sweden                                                   663
# Russian Federation                                       532
# ...

# %%
fig, ax = plt.subplots(1,1, figsize=(12, 7))
x.boxplot('Salary', 'Country', ax=ax)
plt.suptitle('Salary (US$) v Country')
plt.title('')
plt.ylabel('Salary')
plt.xticks(rotation=90)
plt.show()

# %%
x=x[x['Salary'] <= 10000000]
x=x[x['Salary']>=0]
x=x[x['Country']!='Other']

# %%
fig, ax = plt.subplots(1,1, figsize=(12, 7))
x.boxplot('Salary', 'Country', ax=ax)
plt.suptitle('Salary (US$) v Country')
plt.title('')
plt.ylabel('Salary')
plt.xticks(rotation=90)
plt.show()

# %%
x=x[x['Salary'] <= 2000000]
x=x[x['Salary']>=0]
x=x[x['Country']!='Other']

# %%
fig, ax = plt.subplots(1,1, figsize=(12, 7))
x.boxplot('Salary', 'Country', ax=ax)
plt.suptitle('Salary (US$) v Country')
plt.title('')
plt.ylabel('Salary')
plt.xticks(rotation=90)
plt.show()

# %%
x=x[x['Salary'] <= 250000]
x=x[x['Salary']>=10000]
x=x[x['Country']!='Other']

# %%
fig, ax = plt.subplots(1,1, figsize=(12, 7))
x.boxplot('Salary', 'Country', ax=ax)
plt.suptitle('Salary (US$) v Country')
plt.title('')
plt.ylabel('Salary')
plt.xticks(rotation=90)
plt.show()

# %%
x['YearsCodePro'].unique()
# Out:
# array(['5', '17', '6', '2', '10', '4', '22', '20', '9', '14', '21', '15',
#        '3', '25', '7', '8', '12', '19', '1', '24', '11', '23',
#        'Less than 1 year', '18', '40', '37', '46', '13', '32', '31', '39',
#        '27', '28', '16', '30', '34', '35', '26', '42', '38', '36', '43',
#        '41', '44', '29', '33', 'More than 50 years', '45', '48', '50',
#        '47', '49'], dtype=object)

# %%
def clean_exp(x):
    if x=='Less than 1 year':
        return 0.5
    if x=='More than 50 years':
        return 50.0
    return float(x)
x['YearsCodePro']=x['YearsCodePro'].apply(clean_exp)

# %%
x['YearsCodePro'].unique()
# Out:
# array([ 5. , 17. ,  6. ,  2. , 10. ,  4. , 22. , 20. ,  9. , 14. , 21. ,
#        15. ,  3. , 25. ,  7. ,  8. , 12. , 19. ,  1. , 24. , 11. , 23. ,
#         0.5, 18. , 40. , 37. , 46. , 13. , 32. , 31. , 39. , 27. , 28. ,
#        16. , 30. , 34. , 35. , 26. , 42. , 38. , 36. , 43. , 41. , 44. ,
#        29. , 33. , 50. , 45. , 48. , 47. , 49. ])

# %%
x['EdLevel'].unique()
# Out:
# array(['Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#        'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#        'Something else', 'Associate degree (A.A., A.S., etc.)',
#        'Some college/university study without earning a degree',
#        'Professional degree (JD, MD, etc.)',
#        'Other doctoral degree (Ph.D., Ed.D., etc.)',
#        'Primary/elementary school'], dtype=object)

# %%
def clean_edu_level(x):
    if x=='Master’s degree (M.A., M.S., M.Eng., MBA, etc.)':
        return 'Master’s degree'
    if x=='Bachelor’s degree (B.A., B.S., B.Eng., etc.)':
        return 'Bachelor’s degree'
    if 'Professional degree' in x or 'Other doctoral' in x:
        return 'Post grad'
    
    return 'Less than a Bachelors'

x['EdLevel'] = x['EdLevel'].apply(clean_edu_level)

# %%
x['EdLevel'].unique()
# Out:
# array(['Master’s degree', 'Bachelor’s degree', 'Less than a Bachelors',
#        'Post grad'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_edu=LabelEncoder()
x['EdLevel'] = le_edu.fit_transform(x['EdLevel'])
x["EdLevel"].unique()
# Out:
# array([2, 0, 1, 3])

# %%
le_Country=LabelEncoder()
x['Country'] = le_Country.fit_transform(x['Country'])
x['Country'].unique()
# Out:
# array([37, 19, 22, 38,  8,  2, 20,  6, 13, 27, 25, 12,  5, 33, 32, 35, 29,
#        16,  4, 30, 21, 34, 31,  7, 11,  9,  1, 14, 28,  0, 15, 36, 10, 17,
#        18,  3, 26, 23, 24])

# %%
X=x.drop('Salary',axis=1)
y=x['Salary']

# %%
#X=X.drop([['YearsCode','Employment']],axis=1)
X=X.drop('Employment',axis=1)

# %%
X
# Out:
#        Country  EdLevel YearsCode  YearsCodePro
# 2           37        2        14           5.0
# 3           19        0        20          17.0
# 8           22        2         6           6.0
# 10          37        0         5           2.0
# 11          38        0        12          10.0
# ...        ...      ...       ...           ...
# 73116       38        0        21          16.0
# 73118       24        0         4           3.0
# 73119       38        0         5           1.0
# 73120       32        0         6           2.0
# 73121       37        2        10           3.0
#
# [29054 rows x 4 columns]

# %%
X=X.drop('YearsCode',axis=1)
X
# Out:
#        Country  EdLevel  YearsCodePro
# 2           37        2           5.0
# 3           19        0          17.0
# 8           22        2           6.0
# 10          37        0           2.0
# 11          38        0          10.0
# ...        ...      ...           ...
# 73116       38        0          16.0
# 73118       24        0           3.0
# 73119       38        0           1.0
# 73120       32        0           2.0
# 73121       37        2           3.0
#
# [29054 rows x 3 columns]

# %%
from sklearn.linear_model import LinearRegression
linear_reg=LinearRegression()
linear_reg.fit(X,y.values)
# Out:
# LinearRegression()

# %%
y_pred=linear_reg.predict(X)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
error = np.sqrt(mean_squared_error(y, y_pred))
error
# Out:
# 46595.50907297381

# %%
from sklearn.tree import DecisionTreeRegressor
dec_tree_reg = DecisionTreeRegressor(random_state=0)
dec_tree_reg.fit(X, y.values)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred = dec_tree_reg.predict(X)

# %%
error = np.sqrt(mean_squared_error(y, y_pred))
print("${:,.02f}".format(error))
# Out:
# $33,445.40

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest_reg = RandomForestRegressor(random_state=0)
random_forest_reg.fit(X, y.values)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred = random_forest_reg.predict(X)

# %%
error = np.sqrt(mean_squared_error(y, y_pred))
print("${:,.02f}".format(error))
# Out:
# $33,588.99

# %%
from sklearn.model_selection import GridSearchCV

max_depth = [None, 2,4,6,8,10,12]
parameters = {"max_depth": max_depth}

regressor = DecisionTreeRegressor(random_state=0)
gs = GridSearchCV(regressor, parameters, scoring='neg_mean_squared_error')
gs.fit(X, y.values)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(random_state=0),
#              param_grid={'max_depth': [None, 2, 4, 6, 8, 10, 12]},
#              scoring='neg_mean_squared_error')

# %%
regressor = gs.best_estimator_

regressor.fit(X, y.values)
y_pred = regressor.predict(X)
error = np.sqrt(mean_squared_error(y, y_pred))
print("${:,.02f}".format(error))
# Out:
# $35,441.48

# %%
X
# Out:
#        Country  EdLevel  YearsCodePro
# 2           37        2           5.0
# 3           19        0          17.0
# 8           22        2           6.0
# 10          37        0           2.0
# 11          38        0          10.0
# ...        ...      ...           ...
# 73116       38        0          16.0
# 73118       24        0           3.0
# 73119       38        0           1.0
# 73120       32        0           2.0
# 73121       37        2           3.0
#
# [29054 rows x 3 columns]

# %%
z=np.array([['India','Bachelor’s degree',10]])

# %%
z
# Out:
# array([['India', 'Bachelor’s degree', '10']], dtype='<U17')

# %%
z[:, 0] = le_Country.transform(z[:,0])
z[:, 1] = le_edu.transform(z[:,1])
z = z.astype(float)
z
# Out:
# array([[16.,  0., 10.]])

# %%
y_pred=regressor.predict(z)
y_pred
# Out:
# C:\Users\prami\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([40752.04545455])

# %%
import pickle

# %%
data = {"model": regressor, "le_Country": le_Country, "le_edu": le_edu}
with open('saved_steps.pkl', 'wb') as file:
    pickle.dump(data, file)

# %%
with open('saved_steps.pkl', 'rb') as file:
    data = pickle.load(file)

regressor_loaded = data["model"]
le_country = data["le_Country"]
le_education = data["le_edu"]

# %%
y_pred = regressor_loaded.predict(z)
y_pred
# Out:
# C:\Users\prami\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([40752.04545455])
